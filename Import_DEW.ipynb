# %%
import pandas as pd
import dill

# %% [markdown]
# # Import DEW 2019 Aqueous Species
#
# **To do:**
# - Change the code to use a more obvious folder name than 'working'
#
# This notebook runs the code required to generate a database from a set of DEW parameters.
#
# Aaron Wolf wrote functions that make this process easier to implement, originally for use in his carbonated mantle demonstration. The following line runs this file, therefore defining the functions written within it.

# %%
# %run core.ipynb
# Out:
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/rubicon/objc/ctypes_patch.py:24: UserWarning: rubicon.objc.ctypes_patch has only been tested with Python 3.4 through 3.6. The current version is sys.version_info(major=3, minor=7, micro=6, releaselevel='final', serial=0). Most likely things will work properly, but you may experience crashes if Python's internals have changed significantly.
#   .format(sys.version_info)
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# The HKF equations are developed in the previous notebook and setup there as a coder module. This is a pre-requisite for this notebook, and so this line runs the previous notebook.

# %%
# %run HKF_Equations.ipynb

# %% [markdown]
# ## Import and process the DEW database
#
# I have extracted the aqueous species parameters from the DEW "Aqueous Species Options" worksheet. I renamed some of the complexes so that conventions are applied more consistently. I added a column expressing the formulae in the format require by ENKI. For complexes where their parameters are estimated, this estimation must be done by the coder module, I do not import the DEW spreadsheet calculated estimates.

# %%
dew = pd.read_csv('dew2019_cleaned.csv')
dew = dew.fillna(0)
dew
# Out:
#                name    symbol       formula   G_ref     H_ref  S_ref  \
# 0        acetate,aq   CH3COO-  C(2)H(3)O(2)  -88270 -116180.0  20.60
# 1    acetic-acid,aq   CH3COOH  C(2)H(4)O(2)  -94760 -116100.0  42.70
# 2               Ag+     Ag(+)         Ag(1)   18427   25275.0  17.54
# 3           AgCl,aq   AgCl(0)    Ag(1)Cl(1)  -17450  -18270.0  34.10
# 4            AgCl2-  AgCl2(-)    Ag(1)Cl(2)  -51560  -61130.0  47.00
# ..              ...       ...           ...     ...       ...    ...
# 223            Yb+3    Yb(+3)         Yb(1) -153000 -160300.0 -56.90
# 224            Zn+2    Zn(+2)         Zn(1)  -35200  -36660.0 -26.20
# 225           ZnCl+   ZnCl(+)    Zn(1)Cl(1)  -66850  -66240.0  23.00
# 226        ZnCl2,aq  ZnCl2(0)    Zn(1)Cl(2)  -98300 -109080.0  27.03
# 227          ZnCl3-  ZnCl3(-)    Zn(1)Cl(3) -129310 -151060.0  25.00
#
#          V_ref     Cp_ref  omega0  z  ...  prd_ac  compl  gas         a1  \
# 0    40.499926   6.311743  1.3182 -1  ...       0      0    0  10.018000
# 1    52.010022  41.083552 -0.0760  0  ...       0      0    0  11.500000
# 2    -0.800078   7.899675  0.2160  1  ...       1      0    0   2.046420
# 3    27.000000   6.700094 -0.0380  0  ...       1      1    0   6.745843
# 4    53.000000   7.699896  0.9169 -1  ...       1      1    0  12.253325
# ..         ...        ...     ... ..  ...     ...    ...  ...        ...
# 223 -44.499994 -36.399634  2.4443  3  ...       1      0    0  -9.223325
# 224 -24.300094  -6.300282  1.4574  2  ...       1      0    0  -1.417424
# 225   4.800000  19.899909  0.2025  1  ...       1      1    0   2.549738
# 226  26.000000  34.660101 -0.0380  0  ...       1      1    0   6.551633
# 227  43.900000  41.970000  1.2513 -1  ...       1      1    0  10.646411
#
#            a2         a3        a4         c1         c2  \
# 0    2.809000   6.720000 -2.894100  26.300000  -3.860000
# 1    5.500000   1.670000 -2.870000  44.900000  -2.630000
# 2   -4.387714   7.018169 -2.597612  12.786274  -1.425436
# 3    2.139576   3.044087 -2.867450   9.743185  -1.669791
# 4    7.383245  -1.352680 -3.084223  19.126467  -1.466131
# ..        ...        ...       ...        ...        ...
# 223 -1.432516  14.532520 -2.719780   7.353108 -10.449205
# 224 -9.478710   9.977699 -2.387150  15.901037  -4.317967
# 225 -1.855533   6.393947 -2.702292  19.694777   1.019011
# 226  1.954668   3.199130 -2.859806  26.129473   4.025663
# 227  5.853303  -0.069838 -3.020976  42.291632   5.514689
#
#                                               comments
# 0    revised January 26th, 2016; new a1 value from ...
# 1                             Plyasunov & Shock (2001)
# 2    Shock & Helgeson (1988) revised with new predi...
# 3    Sverjensky et al. (1997) with new V greater th...
# 4    Sverjensky et al. (1997) with new V greater th...
# ..                                                 ...
# 223  Shock & Helgeson (1988) revised with new predi...
# 224  Shock & Helgeson (1988) revised with new predi...
# 225  Sverjensky et al. (1997) with revised a1 equal...
# 226  Sverjensky et al. (1997) with revised a1 equal...
# 227  Sverjensky et al. (1997) with revised a1 equal...
#
# [228 rows x 21 columns]

# %% [markdown]
# The parameters given in the DEW spreadsheet are multiplied by factors of 10 for easier display, and the units of energy are colories not Joules. This can be fixed here:

# %%
multipliers = {'a1': 4.184/10,
               'a2': 4.184*100,
               'a3': 4.184,
               'a4': 4.184*1e4,
               'c1': 4.184,
               'c2': 4.184*1e4,
               'G_ref': 4.184,
               'H_ref': 4.184,
               'S_ref': 4.184,
               'V_ref': 0.1,
               'Cp_ref': 4.184,
               'omega0': 4.184*1e5}

for col in list(multipliers.keys()):
    dew[col] = dew[col] * multipliers[col]

dew
# Out:
#                name    symbol       formula       G_ref      H_ref      S_ref  \
# 0        acetate,aq   CH3COO-  C(2)H(3)O(2) -369321.680 -486097.12   86.19040
# 1    acetic-acid,aq   CH3COOH  C(2)H(4)O(2) -396475.840 -485762.40  178.65680
# 2               Ag+     Ag(+)         Ag(1)   77098.568  105750.60   73.38736
# 3           AgCl,aq   AgCl(0)    Ag(1)Cl(1)  -73010.800  -76441.68  142.67440
# 4            AgCl2-  AgCl2(-)    Ag(1)Cl(2) -215727.040 -255767.92  196.64800
# ..              ...       ...           ...         ...        ...        ...
# 223            Yb+3    Yb(+3)         Yb(1) -640152.000 -670695.20 -238.06960
# 224            Zn+2    Zn(+2)         Zn(1) -147276.800 -153385.44 -109.62080
# 225           ZnCl+   ZnCl(+)    Zn(1)Cl(1) -279700.400 -277148.16   96.23200
# 226        ZnCl2,aq  ZnCl2(0)    Zn(1)Cl(2) -411287.200 -456390.72  113.09352
# 227          ZnCl3-  ZnCl3(-)    Zn(1)Cl(3) -541033.040 -632035.04  104.60000
#
#         V_ref      Cp_ref      omega0  z  ...  prd_ac  compl  gas        a1  \
# 0    4.049993   26.408331   551534.88 -1  ...       0      0    0  4.191531
# 1    5.201002  171.893580   -31798.40  0  ...       0      0    0  4.811600
# 2   -0.080008   33.052241    90374.40  1  ...       1      0    0  0.856222
# 3    2.700000   28.033192   -15899.20  0  ...       1      1    0  2.822461
# 4    5.300000   32.216365   383630.96 -1  ...       1      1    0  5.126791
# ..        ...         ...         ... ..  ...     ...    ...  ...       ...
# 223 -4.449999 -152.296070  1022695.12  3  ...       1      0    0 -3.859039
# 224 -2.430009  -26.360379   609776.16  2  ...       1      0    0 -0.593050
# 225  0.480000   83.261218    84726.00  1  ...       1      1    0  1.066810
# 226  2.600000  145.017864   -15899.20  0  ...       1      1    0  2.741203
# 227  4.390000  175.602480   523543.92 -1  ...       1      1    0  4.454458
#
#               a2         a3             a4          c1             c2  \
# 0    1175.285600  28.116480 -121089.144000  110.039200 -161502.400000
# 1    2301.200000   6.987280 -120080.800000  187.861600 -110039.200000
# 2   -1835.819346  29.364018 -108684.082816   53.497768  -59640.249478
# 3     895.198426  12.736460 -119974.110301   40.765485  -69864.051884
# 4    3089.149764  -5.659614 -129043.905131   80.025136  -61342.929492
# ..           ...        ...            ...         ...            ...
# 223  -599.364582  60.804063 -113795.586832   30.765404 -437194.758120
# 224 -3965.892286  41.746694  -99878.361272   66.529939 -180663.755263
# 225  -776.354860  26.752275 -113063.908995   82.402946   42635.437729
# 226   817.833260  13.385159 -119654.282705  109.325714  168433.725945
# 227  2449.022051  -0.292204 -126397.617138  176.948188  230734.587760
#
#                                               comments
# 0    revised January 26th, 2016; new a1 value from ...
# 1                             Plyasunov & Shock (2001)
# 2    Shock & Helgeson (1988) revised with new predi...
# 3    Sverjensky et al. (1997) with new V greater th...
# 4    Sverjensky et al. (1997) with new V greater th...
# ..                                                 ...
# 223  Shock & Helgeson (1988) revised with new predi...
# 224  Shock & Helgeson (1988) revised with new predi...
# 225  Sverjensky et al. (1997) with revised a1 equal...
# 226  Sverjensky et al. (1997) with revised a1 equal...
# 227  Sverjensky et al. (1997) with revised a1 equal...
#
# [228 rows x 21 columns]

# %% [markdown]
# Create a function to generate the parameter dictionary required for each phase by the coder module. Create a name for the species that can be used in filenames.

# %%
def HKF_params(species='H+',Formula='', z=0.0,
                   G_ref=0.0, S_ref=0.0, V_ref=0.0, Cp_ref = 0.0,
                   a1=0.0, a2=0.0, a3=0.0, a4=0.0,
                   c1=0.0, c2=0.0, omega0=0.0,
                   theta=228.0, Psi=2600.0, eta=694657.0, rH=3.082,
                   T_r=298.15, P_r=1.0,
                   compl=0,gas=0,prd_ac=0,prd_omega=0):
    
    species_name = species
    
    if species_name[-1] == '-':
        species_name = species_name[:-1]+'_n'
    if species_name[-2] == '-':
        species_name = species_name[:-2]+'_n'+species_name[-1]
    species_name = species_name.replace('-','_')
    species_name = species_name.replace('+','_p')
    species_name = species_name.replace('(','_l_')
    species_name = species_name.replace(')','_r_')
        
    species_name = species_name.replace(',','_')
    
    param_dict = {'Phase': species_name,
                  'Formula': Formula,
                  'G_ref':G_ref,
                  'S_ref':S_ref,
                  'v_ref':V_ref,
                  'C_p_ref':Cp_ref,
                  'a1':a1,
                  'a2':a2,
                  'a3':a3,
                  'a4':a4,
                  'c1':c1,
                  'c2':c2,
                  'omega0':omega0,
                  'complex':int(compl),
                  'gas':int(gas),
                  'prd_ac':int(prd_ac),
                  'prd_omega':int(prd_omega),
                  'theta':theta,
                  'Psi':Psi,
                  'eta':eta,
                  'rH':rH,
                  'z':z,
                  'T_r':T_r,
                  'P_r':P_r}
    return param_dict

# %% [markdown]
# ## Create objects for each DEW species
# First, create a dictionary of phase parameters for each species

# %%
phase_params = {}
for i, row in dew.iterrows():
    phase_params[row['name']] = HKF_params(species=row['name'],Formula=row['formula'], z=row['z'],
                   G_ref=row['G_ref'], S_ref=row['S_ref'], V_ref=row['V_ref'], Cp_ref = row['Cp_ref'],
                   a1=row['a1'], a2=row['a2'], a3=row['a3'], a4=row['a4'],
                   c1=row['c1'], c2=row['c2'], omega0=row['omega0'],
                   compl=row['compl'],gas=row['gas'],prd_ac=row['prd_ac'],prd_omega=row['prd_omega'])

# %% [markdown]
# Build the database, including generating the coder files

# %%
mod_name = 'dew2019'
modelDB, codermod = make_custom_database(mod_name,phase_params)
# Out:
# /Users/simonmatthews/Dropbox/projects/ENKI-DEW/eq3wrap/working
# Creating (once only) generic fast model code file string
# Creating (once only) generic model fast code template include file string
# Creating (once only) generic model fast code template code file string
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /Users/simonmatthews/Dropbox/projects/ENKI-DEW/eq3wrap/working/dew2019.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/thermoengine/core.py:468: RuntimeWarning: divide by zero encountered in double_scalars
#   mol_Fe_oxide = Fe_remain/(2*frac_Fe2O3 + 1*frac_FeO)
# /Users/simonmatthews/Dropbox/projects/ENKI-DEW/eq3wrap

# %% [markdown]
# ## Check database
# I'm not sure putting all the species into a database is the right thing to do since they're not individual phases. Consider this later once the necessary functionality has been identified.

# %%
modelDB.phase_info
# Out:
#              abbrev      phase_name formula phase_type endmember_num
# 0               Liq          Liquid           solution            15
# 1        acetate,aq      acetate_aq  C2H3O2       pure             1
# 2    acetic-acid,aq  acetic_acid_aq  C2H4O2       pure             1
# 3               Ag+            Ag_p      Ag       pure             1
# 4           AgCl,aq         AgCl_aq    AgCl       pure             1
# ..              ...             ...     ...        ...           ...
# 225            Zn+2           Zn_p2      Zn       pure             1
# 226           ZnCl+          ZnCl_p    ZnCl       pure             1
# 227        ZnCl2,aq        ZnCl2_aq   ZnCl2       pure             1
# 228          ZnCl3-         ZnCl3_n   ZnCl3       pure             1
# 229             H2O           Water     H2O       pure             1
#
# [230 rows x 5 columns]

# %% [markdown]
# ## Save output phases

# %%
output = {}
for phsnm in phase_params:
    iphs = modelDB.get_phase(phsnm)
    output[phsnm] = iphs
output
# Out:
# {'acetate,aq': <thermoengine.phases.PurePhase at 0x1a3b900dd0>,
#  'acetic-acid,aq': <thermoengine.phases.PurePhase at 0x1a3b900cd0>,
#  'Ag+': <thermoengine.phases.PurePhase at 0x1a36868450>,
#  'AgCl,aq': <thermoengine.phases.PurePhase at 0x1a3b900e10>,
#  'AgCl2-': <thermoengine.phases.PurePhase at 0x1a368682d0>,
#  'Al+3': <thermoengine.phases.PurePhase at 0x1a30c4e1d0>,
#  'AlO2-': <thermoengine.phases.PurePhase at 0x1a3b900990>,
#  'AlO2(SiO2)-': <thermoengine.phases.PurePhase at 0x1a3b900f50>,
#  'Ar,aq': <thermoengine.phases.PurePhase at 0x1a3b900110>,
#  'Au+': <thermoengine.phases.PurePhase at 0x1a3b900290>,
#  'Au+3': <thermoengine.phases.PurePhase at 0x1a30c8a090>,
#  'B(OH)3,aq': <thermoengine.phases.PurePhase at 0x1a3b900f90>,
#  'Ba+2': <thermoengine.phases.PurePhase at 0x1a3b900590>,
#  'BaCl+': <thermoengine.phases.PurePhase at 0x1a3b900310>,
#  'Be+2': <thermoengine.phases.PurePhase at 0x1a36868790>,
#  'benzene,aq': <thermoengine.phases.PurePhase at 0x1a30c4e9d0>,
#  'BO(OH),aq': <thermoengine.phases.PurePhase at 0x1a30a25f90>,
#  'BO2-': <thermoengine.phases.PurePhase at 0x1a306da5d0>,
#  'Br-': <thermoengine.phases.PurePhase at 0x1a3b955f50>,
#  'Ca(HCO3)+': <thermoengine.phases.PurePhase at 0x1a3b8fef50>,
#  'Ca(HCOO)+': <thermoengine.phases.PurePhase at 0x1a3b8fe9d0>,
#  'Ca(HSiO3)+': <thermoengine.phases.PurePhase at 0x1a3b8fee50>,
#  'Ca(OH)+': <thermoengine.phases.PurePhase at 0x1a3b8fe150>,
#  'Ca+2': <thermoengine.phases.PurePhase at 0x1a30c4e310>,
#  'CaCl+': <thermoengine.phases.PurePhase at 0x1a3b8fe2d0>,
#  'CaCl2,aq': <thermoengine.phases.PurePhase at 0x1a3b90b910>,
#  'CaCO3,aq': <thermoengine.phases.PurePhase at 0x1a3b8fe210>,
#  'CaO,aq': <thermoengine.phases.PurePhase at 0x1a3b8fe7d0>,
#  'CaSO4,aq': <thermoengine.phases.PurePhase at 0x1a30c79690>,
#  'Cd+2': <thermoengine.phases.PurePhase at 0x1a36868310>,
#  'Ce+3': <thermoengine.phases.PurePhase at 0x1a3ba0de10>,
#  'Ce+4': <thermoengine.phases.PurePhase at 0x1a3b8fe750>,
#  'Cl-': <thermoengine.phases.PurePhase at 0x1a3b8fe590>,
#  'CN-': <thermoengine.phases.PurePhase at 0x1a3b8f9c10>,
#  'CO,aq': <thermoengine.phases.PurePhase at 0x1a3b8f9110>,
#  'Co+2': <thermoengine.phases.PurePhase at 0x1a30c57210>,
#  'Co+3': <thermoengine.phases.PurePhase at 0x1a3b8f9fd0>,
#  'CO2,aq': <thermoengine.phases.PurePhase at 0x1a3b8f9390>,
#  'CO3-2': <thermoengine.phases.PurePhase at 0x1a3b8f9490>,
#  'Cr+2': <thermoengine.phases.PurePhase at 0x1a29f73bd0>,
#  'Cr+3': <thermoengine.phases.PurePhase at 0x1a36868750>,
#  'Cr2O7-2': <thermoengine.phases.PurePhase at 0x1a30c3e990>,
#  'CrO4-2': <thermoengine.phases.PurePhase at 0x1a30c67f90>,
#  'Cs+': <thermoengine.phases.PurePhase at 0x1a29ae8c90>,
#  'Cu+': <thermoengine.phases.PurePhase at 0x1a3b8f9910>,
#  'Cu+2': <thermoengine.phases.PurePhase at 0x1a30c5d990>,
#  'diglycine,aq': <thermoengine.phases.PurePhase at 0x1a3b8f9750>,
#  'diketopiper,aq': <thermoengine.phases.PurePhase at 0x1a3b8f99d0>,
#  'Dy+3': <thermoengine.phases.PurePhase at 0x1a3b8f5250>,
#  'Er+3': <thermoengine.phases.PurePhase at 0x1a3b8f5410>,
#  'ethane,aq': <thermoengine.phases.PurePhase at 0x1a309cd650>,
#  'ethanol,aq': <thermoengine.phases.PurePhase at 0x1a3b8f5510>,
#  'ethylene,aq': <thermoengine.phases.PurePhase at 0x1a30d67790>,
#  'Eu+2': <thermoengine.phases.PurePhase at 0x1a3b8f5850>,
#  'Eu+3': <thermoengine.phases.PurePhase at 0x1a3b8f5910>,
#  'F-': <thermoengine.phases.PurePhase at 0x1a3b8f55d0>,
#  'Fe(CH3COO)+': <thermoengine.phases.PurePhase at 0x1a3b8f5ad0>,
#  'Fe(CH3COO)2,aq': <thermoengine.phases.PurePhase at 0x1a2af176d0>,
#  'Fe(HCOO)+': <thermoengine.phases.PurePhase at 0x1a309dbd10>,
#  'Fe(HSiO3)+': <thermoengine.phases.PurePhase at 0x1a36868390>,
#  'Fe(OH)+': <thermoengine.phases.PurePhase at 0x1a3ba91290>,
#  'Fe+2': <thermoengine.phases.PurePhase at 0x1a30c4e550>,
#  'Fe+3': <thermoengine.phases.PurePhase at 0x1a3b8f1650>,
#  'FeCl+': <thermoengine.phases.PurePhase at 0x1a30d2fed0>,
#  'FeCl+2': <thermoengine.phases.PurePhase at 0x1a3b8edf10>,
#  'FeCl2,aq': <thermoengine.phases.PurePhase at 0x1a3b8ed190>,
#  'FeCl2+': <thermoengine.phases.PurePhase at 0x1a3b8ed490>,
#  'FeCl3,aq': <thermoengine.phases.PurePhase at 0x1a3b8ed510>,
#  'FeCl4-': <thermoengine.phases.PurePhase at 0x1a3b8ed3d0>,
#  'FeO,aq': <thermoengine.phases.PurePhase at 0x1a3b8edf90>,
#  'formate,aq': <thermoengine.phases.PurePhase at 0x1a3ba63710>,
#  'formic-acid,aq': <thermoengine.phases.PurePhase at 0x1a3b8e4e90>,
#  'Ga+3': <thermoengine.phases.PurePhase at 0x1a3b8e4890>,
#  'Gd+3': <thermoengine.phases.PurePhase at 0x1a30c3e510>,
#  'glutamate-': <thermoengine.phases.PurePhase at 0x1a30c4e2d0>,
#  'glutamic-ac,aq': <thermoengine.phases.PurePhase at 0x1a30bbe3d0>,
#  'glutamine,aq': <thermoengine.phases.PurePhase at 0x1a3b8e4790>,
#  'glutarate-': <thermoengine.phases.PurePhase at 0x1a30bfcd50>,
#  'glutaric-ac,aq': <thermoengine.phases.PurePhase at 0x1a3b8e4cd0>,
#  'glycinate-': <thermoengine.phases.PurePhase at 0x1a3b94f090>,
#  'glycine,aq': <thermoengine.phases.PurePhase at 0x1a3712f6d0>,
#  'glycolate-': <thermoengine.phases.PurePhase at 0x1a3b8ddd90>,
#  'glycolic-ac,aq': <thermoengine.phases.PurePhase at 0x1a3b8dd2d0>,
#  'H-succinate,aq': <thermoengine.phases.PurePhase at 0x1a3b8dd250>,
#  'H+': <thermoengine.phases.PurePhase at 0x1a3b8dd5d0>,
#  'H2,aq': <thermoengine.phases.PurePhase at 0x1a3b8dded0>,
#  'H2AsO3-': <thermoengine.phases.PurePhase at 0x1a3b8dd710>,
#  'H2AsO4-': <thermoengine.phases.PurePhase at 0x1a30a25ed0>,
#  'H2CO3,aq': <thermoengine.phases.PurePhase at 0x1a3b8dd6d0>,
#  'H2P2O7-2': <thermoengine.phases.PurePhase at 0x1a30bbe390>,
#  'H2PO4-': <thermoengine.phases.PurePhase at 0x1a3b8dd790>,
#  'H2S,aq': <thermoengine.phases.PurePhase at 0x1a3b8ddad0>,
#  'H2VO4-': <thermoengine.phases.PurePhase at 0x1a3b8ddc10>,
#  'H3P2O7-': <thermoengine.phases.PurePhase at 0x1a3b8dd950>,
#  'H3PO4,aq': <thermoengine.phases.PurePhase at 0x1a309dbd90>,
#  'HAlO2,aq': <thermoengine.phases.PurePhase at 0x1a3b8dbf50>,
#  'HAsO4-2': <thermoengine.phases.PurePhase at 0x1a3b8db590>,
#  'HCl,aq': <thermoengine.phases.PurePhase at 0x1a3b8db690>,
#  'HCN,aq': <thermoengine.phases.PurePhase at 0x1a3b8db750>,
#  'HCO3-': <thermoengine.phases.PurePhase at 0x1a3b8db8d0>,
#  'HCrO4-': <thermoengine.phases.PurePhase at 0x1a368683d0>,
#  'He,aq': <thermoengine.phases.PurePhase at 0x1a3b8dbed0>,
#  'hexane,aq': <thermoengine.phases.PurePhase at 0x1a30d6fa50>,
#  'HFeO2-': <thermoengine.phases.PurePhase at 0x1a3b8db990>,
#  'Hg+2': <thermoengine.phases.PurePhase at 0x1a3b8dbd10>,
#  'Hg2+2': <thermoengine.phases.PurePhase at 0x1a30c271d0>,
#  'Ho+3': <thermoengine.phases.PurePhase at 0x1a3b8dbb90>,
#  'HO2-': <thermoengine.phases.PurePhase at 0x1a3b8db250>,
#  'HPO4-2': <thermoengine.phases.PurePhase at 0x1a3b8db0d0>,
#  'HS-': <thermoengine.phases.PurePhase at 0x1a3b8dbe50>,
#  'HSe-': <thermoengine.phases.PurePhase at 0x1a30c27650>,
#  'HSeO3-': <thermoengine.phases.PurePhase at 0x1a30c85ed0>,
#  'HSeO4-': <thermoengine.phases.PurePhase at 0x1a30cfe2d0>,
#  'HSiO3-': <thermoengine.phases.PurePhase at 0x1a30cae1d0>,
#  'HSO3-': <thermoengine.phases.PurePhase at 0x1a2a56fa10>,
#  'HSO4-': <thermoengine.phases.PurePhase at 0x1a36868690>,
#  'HSO5-': <thermoengine.phases.PurePhase at 0x1a30c4e610>,
#  'HVO4-2': <thermoengine.phases.PurePhase at 0x1a306d35d0>,
#  'I-': <thermoengine.phases.PurePhase at 0x1a3b8d8d50>,
#  'In+3': <thermoengine.phases.PurePhase at 0x1a3b8d8f50>,
#  'isobutane,aq': <thermoengine.phases.PurePhase at 0x1a3b8d8410>,
#  'K+': <thermoengine.phases.PurePhase at 0x1a3b8d8110>,
#  'KCl,aq': <thermoengine.phases.PurePhase at 0x1a3b8d8f10>,
#  'KOH,aq': <thermoengine.phases.PurePhase at 0x1a3b8d8210>,
#  'Kr,aq': <thermoengine.phases.PurePhase at 0x1a36868210>,
#  'KSO4-': <thermoengine.phases.PurePhase at 0x1a3b8d81d0>,
#  'La+3': <thermoengine.phases.PurePhase at 0x1a3b8d8310>,
#  'lactate-': <thermoengine.phases.PurePhase at 0x1a3b8d5a50>,
#  'lactic-acid,aq': <thermoengine.phases.PurePhase at 0x1a30c3e3d0>,
#  'leucine,aq': <thermoengine.phases.PurePhase at 0x1a3b8d58d0>,
#  'Li+': <thermoengine.phases.PurePhase at 0x1a322c4c50>,
#  'Lu+3': <thermoengine.phases.PurePhase at 0x1a3b8d5e10>,
#  'methane,aq': <thermoengine.phases.PurePhase at 0x1a3b8d5f10>,
#  'methanol,aq': <thermoengine.phases.PurePhase at 0x1a3b8d5650>,
#  'Mg(HCO3)+': <thermoengine.phases.PurePhase at 0x1a3b8d55d0>,
#  'Mg(HSiO3)+': <thermoengine.phases.PurePhase at 0x1a3b8d5050>,
#  'Mg+2': <thermoengine.phases.PurePhase at 0x1a3b8d5b90>,
#  'MgCl+': <thermoengine.phases.PurePhase at 0x1a3b8d5250>,
#  'MgCO3,aq': <thermoengine.phases.PurePhase at 0x1a3b8d53d0>,
#  'MgO,aq': <thermoengine.phases.PurePhase at 0x1a3ba0dd50>,
#  'MgOH+': <thermoengine.phases.PurePhase at 0x1a3b8d5390>,
#  'MgSiO2HCO3+': <thermoengine.phases.PurePhase at 0x1a368688d0>,
#  'MgSO4,aq': <thermoengine.phases.PurePhase at 0x1a3b8d5550>,
#  'Mn+2': <thermoengine.phases.PurePhase at 0x1a30d60b10>,
#  'MnCl+': <thermoengine.phases.PurePhase at 0x1a3b8cff90>,
#  'MnO4-': <thermoengine.phases.PurePhase at 0x1a3b8cffd0>,
#  'MnO4-2': <thermoengine.phases.PurePhase at 0x1a3b900b90>,
#  'MnSO4,aq': <thermoengine.phases.PurePhase at 0x1a3b8cfc10>,
#  'MoO4-2': <thermoengine.phases.PurePhase at 0x1a3b8cf150>,
#  'N2,aq': <thermoengine.phases.PurePhase at 0x1a3b8cf1d0>,
#  'Na(Ac),aq': <thermoengine.phases.PurePhase at 0x1a3b8cf350>,
#  'Na(Ac)2-': <thermoengine.phases.PurePhase at 0x1a3b8cf410>,
#  'Na+': <thermoengine.phases.PurePhase at 0x1a3b8cf8d0>,
#  'NaCl,aq': <thermoengine.phases.PurePhase at 0x1a3b8cf5d0>,
#  'NaCO3-': <thermoengine.phases.PurePhase at 0x1a3b8cf790>,
#  'NaHCO3,aq': <thermoengine.phases.PurePhase at 0x1a3b8cde50>,
#  'NaHSiO3,aq': <thermoengine.phases.PurePhase at 0x1a3b8cded0>,
#  'NaOH,aq': <thermoengine.phases.PurePhase at 0x1a3b8cdcd0>,
#  'Nd+3': <thermoengine.phases.PurePhase at 0x1a3b8cdb10>,
#  'Ne,aq': <thermoengine.phases.PurePhase at 0x1a30c27750>,
#  'NH3,aq': <thermoengine.phases.PurePhase at 0x1a36868150>,
#  'NH4+': <thermoengine.phases.PurePhase at 0x1a3b8cdc10>,
#  'Ni+2': <thermoengine.phases.PurePhase at 0x1a3b8cd290>,
#  'NO2-': <thermoengine.phases.PurePhase at 0x1a30d380d0>,
#  'NO3-': <thermoengine.phases.PurePhase at 0x1a3b8cdd10>,
#  'O2,aq': <thermoengine.phases.PurePhase at 0x1a3b8cd550>,
#  'OH-': <thermoengine.phases.PurePhase at 0x1a3b8cd3d0>,
#  'Pb+2': <thermoengine.phases.PurePhase at 0x1a3b8cd790>,
#  'PbCl+': <thermoengine.phases.PurePhase at 0x1a30d38410>,
#  'PbCl2,aq': <thermoengine.phases.PurePhase at 0x1a3b8cd390>,
#  'PbCl3-': <thermoengine.phases.PurePhase at 0x1a3b8cd950>,
#  'Pd+2': <thermoengine.phases.PurePhase at 0x1a3b8cd810>,
#  'PO4-3': <thermoengine.phases.PurePhase at 0x1a3b8c9d90>,
#  'Pr+3': <thermoengine.phases.PurePhase at 0x1a3b8c92d0>,
#  'propane,aq': <thermoengine.phases.PurePhase at 0x1a3b8c9250>,
#  'propanoate-': <thermoengine.phases.PurePhase at 0x1a3b8c9450>,
#  'propanoic-a,aq': <thermoengine.phases.PurePhase at 0x1a3b8c9510>,
#  'propanol,aq': <thermoengine.phases.PurePhase at 0x1a368686d0>,
#  'Ra+2': <thermoengine.phases.PurePhase at 0x1a3b8c9d50>,
#  'Rb+': <thermoengine.phases.PurePhase at 0x1a36868810>,
#  'ReO4-': <thermoengine.phases.PurePhase at 0x1a3b8c9850>,
#  'Rn,aq': <thermoengine.phases.PurePhase at 0x1a3b8c9a10>,
#  'S2-2': <thermoengine.phases.PurePhase at 0x1a3b8c9c10>,
#  'S2O3-2': <thermoengine.phases.PurePhase at 0x1a306d3690>,
#  'S2O4-2': <thermoengine.phases.PurePhase at 0x1a3b8c9610>,
#  'S2O5-2': <thermoengine.phases.PurePhase at 0x1a3b903790>,
#  'S2O6-2': <thermoengine.phases.PurePhase at 0x1a3b8c9050>,
#  'S2O8-2': <thermoengine.phases.PurePhase at 0x1a3b8c45d0>,
#  'S3-': <thermoengine.phases.PurePhase at 0x1a3b8c4650>,
#  'S3-2': <thermoengine.phases.PurePhase at 0x1a3b8c4790>,
#  'S3O6-2': <thermoengine.phases.PurePhase at 0x1a3b8c4890>,
#  'S4-2': <thermoengine.phases.PurePhase at 0x1a306da450>,
#  'S4O6-2': <thermoengine.phases.PurePhase at 0x1a3b8c4fd0>,
#  'S5-2': <thermoengine.phases.PurePhase at 0x1a3b8c4b50>,
#  'S5O6-2': <thermoengine.phases.PurePhase at 0x1a3b8c4c50>,
#  'Sc+3': <thermoengine.phases.PurePhase at 0x1a3b8c4cd0>,
#  'SeO3-2': <thermoengine.phases.PurePhase at 0x1a3b8c4d90>,
#  'SeO4-2': <thermoengine.phases.PurePhase at 0x1a3b8c4150>,
#  'Si2O4,aq': <thermoengine.phases.PurePhase at 0x1a3b8c4090>,
#  'Si3O6,aq': <thermoengine.phases.PurePhase at 0x1a3b8c4a50>,
#  'SiO2,aq': <thermoengine.phases.PurePhase at 0x1a3b8c16d0>,
#  'Sm+2': <thermoengine.phases.PurePhase at 0x1a3b8c18d0>,
#  'Sm+3': <thermoengine.phases.PurePhase at 0x1a3b8c1990>,
#  'Sn+2': <thermoengine.phases.PurePhase at 0x1a3b8c1b10>,
#  'SO2,aq': <thermoengine.phases.PurePhase at 0x1a3b8c1bd0>,
#  'SO3-2': <thermoengine.phases.PurePhase at 0x1a3b8c1cd0>,
#  'SO4-2': <thermoengine.phases.PurePhase at 0x1a3b90b450>,
#  'Sr+2': <thermoengine.phases.PurePhase at 0x1a3b8c1710>,
#  'SrCl+': <thermoengine.phases.PurePhase at 0x1a3b8c1f90>,
#  'Tb+3': <thermoengine.phases.PurePhase at 0x1a3b8c1410>,
#  'Tl+': <thermoengine.phases.PurePhase at 0x1a3b8c14d0>,
#  'Tl+3': <thermoengine.phases.PurePhase at 0x1a3b8c1150>,
#  'Tm+3': <thermoengine.phases.PurePhase at 0x1a3b8c1210>,
#  'toluene,aq': <thermoengine.phases.PurePhase at 0x1a3b8c1d90>,
#  'U+4': <thermoengine.phases.PurePhase at 0x1a3b8bc8d0>,
#  'UO2+2': <thermoengine.phases.PurePhase at 0x1a3b8bca50>,
#  'urea,aq': <thermoengine.phases.PurePhase at 0x1a3b8bcad0>,
#  'VO+2': <thermoengine.phases.PurePhase at 0x1a3b8bcc50>,
#  'VO2+': <thermoengine.phases.PurePhase at 0x1a3b8bcd50>,
#  'WO4-2': <thermoengine.phases.PurePhase at 0x1a3b8bce10>,
#  'Xe,aq': <thermoengine.phases.PurePhase at 0x1a3712f890>,
#  'Y+3': <thermoengine.phases.PurePhase at 0x1a3b8bc890>,
#  'Yb+2': <thermoengine.phases.PurePhase at 0x1a3b8bc690>,
#  'Yb+3': <thermoengine.phases.PurePhase at 0x1a3b8bc790>,
#  'Zn+2': <thermoengine.phases.PurePhase at 0x1a3b8bc150>,
#  'ZnCl+': <thermoengine.phases.PurePhase at 0x1a309cd250>,
#  'ZnCl2,aq': <thermoengine.phases.PurePhase at 0x1a3b8bcf10>,
#  'ZnCl3-': <thermoengine.phases.PurePhase at 0x1a3b8bc390>}

# %%
with open('DEW2019.pkl','wb') as file:
    dill.dump(output, file)
    file.close()
