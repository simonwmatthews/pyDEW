# %%
import pandas as pd
import dill

# %% [markdown]
# # Import DEW 2019 Aqueous Species
#
# **To do:**
# - Change the code to use a more obvious folder name than 'working'
#
# This notebook runs the code required to generate a database from a set of DEW parameters.
#
# Aaron Wolf wrote functions that make this process easier to implement, originally for use in his carbonated mantle demonstration. The following line runs this file, therefore defining the functions written within it.

# %%
# %run core.ipynb
# Out:
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %% [markdown]
# The HKF equations are developed in the previous notebook and setup there as a coder module. This is a pre-requisite for this notebook, and so this line runs the previous notebook.

# %%
# %run HKF_Equations.ipynb

# %% [markdown]
# ## Import and process the DEW database
#
# I have extracted the aqueous species parameters from the DEW "Aqueous Species Options" worksheet. I renamed some of the complexes so that conventions are applied more consistently. I added a column expressing the formulae in the format require by ENKI. For complexes where their parameters are estimated, this estimation must be done by the coder module, I do not import the DEW spreadsheet calculated estimates.

# %%
dew = pd.read_csv('dew2019_cleaned.csv')
dew = dew.fillna(0)
dew
# Out:
#                name         EQ_name    symbol       formula  include   G_ref  \
# 0        acetate,aq     ACETATE(AQ)   CH3COO-  C(2)H(3)O(2)        1  -88270
# 1    acetic-acid,aq  ACETICACID(AQ)   CH3COOH  C(2)H(4)O(2)        1  -94760
# 2               Ag+             AG+     Ag(+)         Ag(1)        1   18427
# 3           AgCl,aq        AGCL(AQ)   AgCl(0)    Ag(1)Cl(1)        0  -17450
# 4            AgCl2-          AGCL2-  AgCl2(-)    Ag(1)Cl(2)        0  -51560
# ..              ...             ...       ...           ...      ...     ...
# 223            Yb+3            YB+3    Yb(+3)         Yb(1)        0 -153000
# 224            Zn+2            ZN+2    Zn(+2)         Zn(1)        1  -35200
# 225           ZnCl+           ZNCL+   ZnCl(+)    Zn(1)Cl(1)        0  -66850
# 226        ZnCl2,aq       ZNCL2(AQ)  ZnCl2(0)    Zn(1)Cl(2)        0  -98300
# 227          ZnCl3-          ZNCL3-  ZnCl3(-)    Zn(1)Cl(3)        0 -129310
#
#         H_ref  S_ref      V_ref     Cp_ref  ...  prd_ac  compl  gas  \
# 0   -116180.0  20.60  40.499926   6.311743  ...       0      0    0
# 1   -116100.0  42.70  52.010022  41.083552  ...       0      0    0
# 2     25275.0  17.54  -0.800078   7.899675  ...       1      0    0
# 3    -18270.0  34.10  27.000000   6.700094  ...       1      1    0
# 4    -61130.0  47.00  53.000000   7.699896  ...       1      1    0
# ..        ...    ...        ...        ...  ...     ...    ...  ...
# 223 -160300.0 -56.90 -44.499994 -36.399634  ...       1      0    0
# 224  -36660.0 -26.20 -24.300094  -6.300282  ...       1      0    0
# 225  -66240.0  23.00   4.800000  19.899909  ...       1      1    0
# 226 -109080.0  27.03  26.000000  34.660101  ...       1      1    0
# 227 -151060.0  25.00  43.900000  41.970000  ...       1      1    0
#
#             a1        a2         a3        a4         c1         c2  \
# 0    10.018000  2.809000   6.720000 -2.894100  26.300000  -3.860000
# 1    11.500000  5.500000   1.670000 -2.870000  44.900000  -2.630000
# 2     2.046420 -4.387714   7.018169 -2.597612  12.786274  -1.425436
# 3     6.745843  2.139576   3.044087 -2.867450   9.743185  -1.669791
# 4    12.253325  7.383245  -1.352680 -3.084223  19.126467  -1.466131
# ..         ...       ...        ...       ...        ...        ...
# 223  -9.223325 -1.432516  14.532520 -2.719780   7.353108 -10.449205
# 224  -1.417424 -9.478710   9.977699 -2.387150  15.901037  -4.317967
# 225   2.549738 -1.855533   6.393947 -2.702292  19.694777   1.019011
# 226   6.551633  1.954668   3.199130 -2.859806  26.129473   4.025663
# 227  10.646411  5.853303  -0.069838 -3.020976  42.291632   5.514689
#
#                                               comments
# 0    revised January 26th, 2016; new a1 value from ...
# 1                             Plyasunov & Shock (2001)
# 2    Shock & Helgeson (1988) revised with new predi...
# 3    Sverjensky et al. (1997) with new V greater th...
# 4    Sverjensky et al. (1997) with new V greater th...
# ..                                                 ...
# 223  Shock & Helgeson (1988) revised with new predi...
# 224  Shock & Helgeson (1988) revised with new predi...
# 225  Sverjensky et al. (1997) with revised a1 equal...
# 226  Sverjensky et al. (1997) with revised a1 equal...
# 227  Sverjensky et al. (1997) with revised a1 equal...
#
# [228 rows x 23 columns]

# %% [markdown]
# The parameters given in the DEW spreadsheet are multiplied by factors of 10 for easier display, and the units of energy are colories not Joules. This can be fixed here:

# %%
multipliers = {'a1': 4.184/10,
               'a2': 4.184*100,
               'a3': 4.184,
               'a4': 4.184*1e4,
               'c1': 4.184,
               'c2': 4.184*1e4,
               'G_ref': 4.184,
               'H_ref': 4.184,
               'S_ref': 4.184,
               'V_ref': 0.1,
               'Cp_ref': 4.184,
               'omega0': 4.184*1e5}

for col in list(multipliers.keys()):
    dew[col] = dew[col] * multipliers[col]

dew
# Out:
#                name         EQ_name    symbol       formula  include  \
# 0        acetate,aq     ACETATE(AQ)   CH3COO-  C(2)H(3)O(2)        1
# 1    acetic-acid,aq  ACETICACID(AQ)   CH3COOH  C(2)H(4)O(2)        1
# 2               Ag+             AG+     Ag(+)         Ag(1)        1
# 3           AgCl,aq        AGCL(AQ)   AgCl(0)    Ag(1)Cl(1)        0
# 4            AgCl2-          AGCL2-  AgCl2(-)    Ag(1)Cl(2)        0
# ..              ...             ...       ...           ...      ...
# 223            Yb+3            YB+3    Yb(+3)         Yb(1)        0
# 224            Zn+2            ZN+2    Zn(+2)         Zn(1)        1
# 225           ZnCl+           ZNCL+   ZnCl(+)    Zn(1)Cl(1)        0
# 226        ZnCl2,aq       ZNCL2(AQ)  ZnCl2(0)    Zn(1)Cl(2)        0
# 227          ZnCl3-          ZNCL3-  ZnCl3(-)    Zn(1)Cl(3)        0
#
#           G_ref      H_ref      S_ref     V_ref      Cp_ref  ...  prd_ac  \
# 0   -369321.680 -486097.12   86.19040  4.049993   26.408331  ...       0
# 1   -396475.840 -485762.40  178.65680  5.201002  171.893580  ...       0
# 2     77098.568  105750.60   73.38736 -0.080008   33.052241  ...       1
# 3    -73010.800  -76441.68  142.67440  2.700000   28.033192  ...       1
# 4   -215727.040 -255767.92  196.64800  5.300000   32.216365  ...       1
# ..          ...        ...        ...       ...         ...  ...     ...
# 223 -640152.000 -670695.20 -238.06960 -4.449999 -152.296070  ...       1
# 224 -147276.800 -153385.44 -109.62080 -2.430009  -26.360379  ...       1
# 225 -279700.400 -277148.16   96.23200  0.480000   83.261218  ...       1
# 226 -411287.200 -456390.72  113.09352  2.600000  145.017864  ...       1
# 227 -541033.040 -632035.04  104.60000  4.390000  175.602480  ...       1
#
#      compl  gas        a1           a2         a3             a4          c1  \
# 0        0    0  4.191531  1175.285600  28.116480 -121089.144000  110.039200
# 1        0    0  4.811600  2301.200000   6.987280 -120080.800000  187.861600
# 2        0    0  0.856222 -1835.819346  29.364018 -108684.082816   53.497768
# 3        1    0  2.822461   895.198426  12.736460 -119974.110301   40.765485
# 4        1    0  5.126791  3089.149764  -5.659614 -129043.905131   80.025136
# ..     ...  ...       ...          ...        ...            ...         ...
# 223      0    0 -3.859039  -599.364582  60.804063 -113795.586832   30.765404
# 224      0    0 -0.593050 -3965.892286  41.746694  -99878.361272   66.529939
# 225      1    0  1.066810  -776.354860  26.752275 -113063.908995   82.402946
# 226      1    0  2.741203   817.833260  13.385159 -119654.282705  109.325714
# 227      1    0  4.454458  2449.022051  -0.292204 -126397.617138  176.948188
#
#                 c2                                           comments
# 0   -161502.400000  revised January 26th, 2016; new a1 value from ...
# 1   -110039.200000                           Plyasunov & Shock (2001)
# 2    -59640.249478  Shock & Helgeson (1988) revised with new predi...
# 3    -69864.051884  Sverjensky et al. (1997) with new V greater th...
# 4    -61342.929492  Sverjensky et al. (1997) with new V greater th...
# ..             ...                                                ...
# 223 -437194.758120  Shock & Helgeson (1988) revised with new predi...
# 224 -180663.755263  Shock & Helgeson (1988) revised with new predi...
# 225   42635.437729  Sverjensky et al. (1997) with revised a1 equal...
# 226  168433.725945  Sverjensky et al. (1997) with revised a1 equal...
# 227  230734.587760  Sverjensky et al. (1997) with revised a1 equal...
#
# [228 rows x 23 columns]

# %% [markdown]
# Create a function to generate the parameter dictionary required for each phase by the coder module. Create a name for the species that can be used in filenames.

# %%
def HKF_params(species='H+',Formula='', z=0.0,
                   G_ref=0.0, S_ref=0.0, V_ref=0.0, Cp_ref = 0.0,
                   a1=0.0, a2=0.0, a3=0.0, a4=0.0,
                   c1=0.0, c2=0.0, omega0=0.0,
                   theta=228.0, Psi=2600.0, eta=694657.0, rH=3.082,
                   T_r=298.15, P_r=1.0):
    
    species_name = species
    
    if species_name[-1] == '-':
        species_name = species_name[:-1]+'_n'
    if species_name[-2] == '-':
        species_name = species_name[:-2]+'_n'+species_name[-1]
    species_name = species_name.replace('-','_')
    species_name = species_name.replace('+','_p')
    species_name = species_name.replace('(','_l_')
    species_name = species_name.replace(')','_r_')
        
    species_name = species_name.replace(',','_')
    
    param_dict = {'Phase': species_name,
                  'Formula': Formula,
                  'G_ref':G_ref,
                  'S_ref':S_ref,
                  'v_ref':V_ref,
                  'C_p_ref':Cp_ref,
                  'a1':a1,
                  'a2':a2,
                  'a3':a3,
                  'a4':a4,
                  'c1':c1,
                  'c2':c2,
                  'omega0':omega0,
                  'theta':theta,
                  'Psi':Psi,
                  'eta':eta,
                  'rH':rH,
                  'z':z,
                  'T_r':T_r,
                  'P_r':P_r}
    return param_dict

# %% [markdown]
# ## Create objects for each DEW species
# First, create a dictionary of phase parameters for each species
#
# **NOTE: To use the 'prettier' complex names that are not entirely capitalised, change row['EQ_name'] to row['name']**. Capitalised names ensure compatibility with all versions of EQ3 and EQ6.

# %%
phase_params = {}
for i, row in dew.iterrows():
    phase_params[row['EQ_name']] = HKF_params(species=row['EQ_name'],Formula=row['formula'], z=row['z'],
                   G_ref=row['G_ref'], S_ref=row['S_ref'], V_ref=row['V_ref'], Cp_ref = row['Cp_ref'],
                   a1=row['a1'], a2=row['a2'], a3=row['a3'], a4=row['a4'],
                   c1=row['c1'], c2=row['c2'], omega0=row['omega0'])

# %% [markdown]
# Build the database, including generating the coder files

# %%
mod_name = 'dew2019'
modelDB, codermod = make_custom_database(mod_name,phase_params,working_dir='dew2019_coderfiles')
# Out:
# /Users/simonmatthews/repos/pyQ3/dew2019_coderfiles
# Creating (once only) generic fast model code file string
# Creating (once only) generic model fast code template include file string
# Creating (once only) generic model fast code template code file string
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# ...
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# Creating include file ...
# ... done!
# Creating code file ...
# ... done
# Writing include file to working directory ...
# Writing code file to working directory ...
# Writing pyxbld file to working directory ...
# writing pyx file to working directory ...
# Compiling code and Python bindings ...
# Success! Import the module named  dew2019
# /Users/simonmatthews/opt/anaconda3/lib/python3.7/site-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /Users/simonmatthews/repos/pyQ3/dew2019_coderfiles/dew2019.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# /Users/simonmatthews/repos/pyQ3

# %% [markdown]
# ## Check database
# I'm not sure putting all the species into a database is the right thing to do since they're not individual phases. Consider this later once the necessary functionality has been identified.

# %%
modelDB.phase_info
# Out:
#              abbrev          phase_name formula phase_type endmember_num
# 0       ACETATE(AQ)     ACETATE_l_AQ_r_  C2H3O2       pure             1
# 1    ACETICACID(AQ)  ACETICACID_l_AQ_r_  C2H4O2       pure             1
# 2               AG+                AG_p      Ag       pure             1
# 3          AGCL(AQ)        AGCL_l_AQ_r_    AgCl       pure             1
# 4            AGCL2-             AGCL2_n   AgCl2       pure             1
# ..              ...                 ...     ...        ...           ...
# 223            YB+3               YB_p3      Yb       pure             1
# 224            ZN+2               ZN_p2      Zn       pure             1
# 225           ZNCL+              ZNCL_p    ZnCl       pure             1
# 226       ZNCL2(AQ)       ZNCL2_l_AQ_r_   ZnCl2       pure             1
# 227          ZNCL3-             ZNCL3_n   ZnCl3       pure             1
#
# [228 rows x 5 columns]

# %% [markdown]
# ## Save output phases

# %%
output = {}
for phsnm in phase_params:
    iphs = modelDB.get_phase(phsnm)
    output[phsnm] = iphs
output
# Out:
# {'ACETATE(AQ)': <thermoengine.phases.PurePhase at 0x7f98755316d0>,
#  'ACETICACID(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f88290>,
#  'AG+': <thermoengine.phases.PurePhase at 0x7f9863f57590>,
#  'AGCL(AQ)': <thermoengine.phases.PurePhase at 0x7f9875616b10>,
#  'AGCL2-': <thermoengine.phases.PurePhase at 0x7f987251a750>,
#  'AL+3': <thermoengine.phases.PurePhase at 0x7f9863f578d0>,
#  'ALO2-': <thermoengine.phases.PurePhase at 0x7f9863f576d0>,
#  'ALO2(SIO2)-': <thermoengine.phases.PurePhase at 0x7f9874dff750>,
#  'AR(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f57850>,
#  'AU+': <thermoengine.phases.PurePhase at 0x7f9874dff810>,
#  'AU+3': <thermoengine.phases.PurePhase at 0x7f986f4ae610>,
#  'B(OH)3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f57cd0>,
#  'BA+2': <thermoengine.phases.PurePhase at 0x7f9863f57110>,
#  'BACL+': <thermoengine.phases.PurePhase at 0x7f9875574710>,
#  'BE+2': <thermoengine.phases.PurePhase at 0x7f9875354b90>,
#  'BENZENE(AQ)': <thermoengine.phases.PurePhase at 0x7f9874dff710>,
#  'BO(OH)(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f571d0>,
#  'BO2-': <thermoengine.phases.PurePhase at 0x7f9875707550>,
#  'BR-': <thermoengine.phases.PurePhase at 0x7f9863f52890>,
#  'CA(HCO3)+': <thermoengine.phases.PurePhase at 0x7f9874dff2d0>,
#  'CA(HCOO)+': <thermoengine.phases.PurePhase at 0x7f9863f52750>,
#  'CA(HSIO3)+': <thermoengine.phases.PurePhase at 0x7f9863f52990>,
#  'CA(OH)+': <thermoengine.phases.PurePhase at 0x7f987e846050>,
#  'CA+2': <thermoengine.phases.PurePhase at 0x7f9863f52950>,
#  'CACL+': <thermoengine.phases.PurePhase at 0x7f9875337b90>,
#  'CACL2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f52ed0>,
#  'CACO3(AQ)': <thermoengine.phases.PurePhase at 0x7f98756bca10>,
#  'CAO(AQ)': <thermoengine.phases.PurePhase at 0x7f98756ca590>,
#  'CASO4(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f52350>,
#  'CD+2': <thermoengine.phases.PurePhase at 0x7f9863f4f890>,
#  'CE+3': <thermoengine.phases.PurePhase at 0x7f9863f4f810>,
#  'CE+4': <thermoengine.phases.PurePhase at 0x7f9863f4fa90>,
#  'CL-': <thermoengine.phases.PurePhase at 0x7f9863f88b90>,
#  'CN-': <thermoengine.phases.PurePhase at 0x7f9863f4f990>,
#  'CO(AQ)': <thermoengine.phases.PurePhase at 0x7f9875574150>,
#  'CO+2': <thermoengine.phases.PurePhase at 0x7f9863f57510>,
#  'CO+3': <thermoengine.phases.PurePhase at 0x7f9863f57490>,
#  'CO2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f4fb10>,
#  'CO3-2': <thermoengine.phases.PurePhase at 0x7f9863f4f710>,
#  'CR+2': <thermoengine.phases.PurePhase at 0x7f9863f4f210>,
#  'CR+3': <thermoengine.phases.PurePhase at 0x7f9863f4f2d0>,
#  'CR2O7-2': <thermoengine.phases.PurePhase at 0x7f9863f4f550>,
#  'CRO4-2': <thermoengine.phases.PurePhase at 0x7f9863f4f390>,
#  'CS+': <thermoengine.phases.PurePhase at 0x7f9875574090>,
#  'CU+': <thermoengine.phases.PurePhase at 0x7f9863f88ad0>,
#  'CU+2': <thermoengine.phases.PurePhase at 0x7f9863f4f690>,
#  'DIGLYCINE(AQ)': <thermoengine.phases.PurePhase at 0x7f9875337e10>,
#  'DIKETOPIPER(AQ)': <thermoengine.phases.PurePhase at 0x7f987500dfd0>,
#  'DY+3': <thermoengine.phases.PurePhase at 0x7f9874dff290>,
#  'ER+3': <thermoengine.phases.PurePhase at 0x7f9863f4fd50>,
#  'ETHANE(AQ)': <thermoengine.phases.PurePhase at 0x7f9875526d50>,
#  'ETHANOL(AQ)': <thermoengine.phases.PurePhase at 0x7f9875707490>,
#  'ETHYLENE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f46790>,
#  'EU+2': <thermoengine.phases.PurePhase at 0x7f9874fbc890>,
#  'EU+3': <thermoengine.phases.PurePhase at 0x7f9863f461d0>,
#  'F-': <thermoengine.phases.PurePhase at 0x7f9863f3ff50>,
#  'FE(CH3COO)+': <thermoengine.phases.PurePhase at 0x7f9863f3fdd0>,
#  'FE(CH3COO)2(AQ)': <thermoengine.phases.PurePhase at 0x7f988ed9bb10>,
#  'FE(HCOO)+': <thermoengine.phases.PurePhase at 0x7f9863f3fed0>,
#  'FE(HSIO3)+': <thermoengine.phases.PurePhase at 0x7f9863f3f410>,
#  'FE(OH)+': <thermoengine.phases.PurePhase at 0x7f9863f3f290>,
#  'FE+2': <thermoengine.phases.PurePhase at 0x7f9863f3f550>,
#  'FE+3': <thermoengine.phases.PurePhase at 0x7f9874dff450>,
#  'FECL+': <thermoengine.phases.PurePhase at 0x7f9863f3f850>,
#  'FECL+2': <thermoengine.phases.PurePhase at 0x7f9863f3f910>,
#  'FECL2(AQ)': <thermoengine.phases.PurePhase at 0x7f987251a710>,
#  'FECL2+': <thermoengine.phases.PurePhase at 0x7f9863f3f710>,
#  'FECL3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3f9d0>,
#  'FECL4-': <thermoengine.phases.PurePhase at 0x7f9863f3f090>,
#  'FEO(AQ)': <thermoengine.phases.PurePhase at 0x7f9874dff210>,
#  'FORMATE(AQ)': <thermoengine.phases.PurePhase at 0x7f987500dd10>,
#  'FORMIC-ACID(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f88bd0>,
#  'GA+3': <thermoengine.phases.PurePhase at 0x7f9863f3af50>,
#  'GD+3': <thermoengine.phases.PurePhase at 0x7f9863f3a810>,
#  'GLUTAMATE-': <thermoengine.phases.PurePhase at 0x7f9863f3a890>,
#  'GLUTAMIC-AC(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3a990>,
#  'GLUTAMINE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3aa50>,
#  'GLUTARATE-': <thermoengine.phases.PurePhase at 0x7f987556e4d0>,
#  'GLUTARIC-AC(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3ac50>,
#  'GLYCINATE-': <thermoengine.phases.PurePhase at 0x7f9863f3ad10>,
#  'GLYCINE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3aed0>,
#  'GLYCOLATE-': <thermoengine.phases.PurePhase at 0x7f9863f57450>,
#  'GLYCOLIC-AC(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3ae10>,
#  'H-SUCCINATE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3a110>,
#  'H+': <thermoengine.phases.PurePhase at 0x7f9863f386d0>,
#  'H2(AQ)': <thermoengine.phases.PurePhase at 0x7f987561de50>,
#  'H2ASO3-': <thermoengine.phases.PurePhase at 0x7f988f3d9bd0>,
#  'H2ASO4-': <thermoengine.phases.PurePhase at 0x7f9863f387d0>,
#  'H2CO3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38910>,
#  'H2P2O7-2': <thermoengine.phases.PurePhase at 0x7f9863f38ad0>,
#  'H2PO4-': <thermoengine.phases.PurePhase at 0x7f9863f38750>,
#  'H2S(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38d50>,
#  'H2VO4-': <thermoengine.phases.PurePhase at 0x7f9863fd9f50>,
#  'H3P207-': <thermoengine.phases.PurePhase at 0x7f9863f38cd0>,
#  'H3PO4(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38f50>,
#  'HALO2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38410>,
#  'HASO4-2': <thermoengine.phases.PurePhase at 0x7f9863f38dd0>,
#  'HCL(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f380d0>,
#  'HCN(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38350>,
#  'HCO3-': <thermoengine.phases.PurePhase at 0x7f9875574190>,
#  'HCRO4-': <thermoengine.phases.PurePhase at 0x7f9874dff4d0>,
#  'HE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f38250>,
#  'HEXANE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f382d0>,
#  'HFEO2-': <thermoengine.phases.PurePhase at 0x7f9863f34c10>,
#  'HG+2': <thermoengine.phases.PurePhase at 0x7f98750071d0>,
#  'HG2+2': <thermoengine.phases.PurePhase at 0x7f987561d210>,
#  'HO+3': <thermoengine.phases.PurePhase at 0x7f9863f34b90>,
#  'HO2-': <thermoengine.phases.PurePhase at 0x7f9863f34f90>,
#  'HPO4-2': <thermoengine.phases.PurePhase at 0x7f9863f346d0>,
#  'HS-': <thermoengine.phases.PurePhase at 0x7f9863f34790>,
#  'HSE-': <thermoengine.phases.PurePhase at 0x7f9863f34190>,
#  'HSEO3-': <thermoengine.phases.PurePhase at 0x7f9863f341d0>,
#  'HSEO4-': <thermoengine.phases.PurePhase at 0x7f986f4ae390>,
#  'HSIO3-': <thermoengine.phases.PurePhase at 0x7f9863fd9e50>,
#  'HSO3-': <thermoengine.phases.PurePhase at 0x7f9874dff690>,
#  'HSO4-': <thermoengine.phases.PurePhase at 0x7f9863f34350>,
#  'HSO5-': <thermoengine.phases.PurePhase at 0x7f9863f34490>,
#  'HVO4-2': <thermoengine.phases.PurePhase at 0x7f9863f31d10>,
#  'I-': <thermoengine.phases.PurePhase at 0x7f9863f31ed0>,
#  'IN+3': <thermoengine.phases.PurePhase at 0x7f988ed9bc50>,
#  'ISOBUTANE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f31f50>,
#  'K+': <thermoengine.phases.PurePhase at 0x7f9863f31990>,
#  'KCL(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f3a750>,
#  'KOH(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f31110>,
#  'KR(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f311d0>,
#  'KSO4-': <thermoengine.phases.PurePhase at 0x7f9863f31250>,
#  'LA+3': <thermoengine.phases.PurePhase at 0x7f9863f313d0>,
#  'LACTATE-': <thermoengine.phases.PurePhase at 0x7f9863f31490>,
#  'LACTIC-ACID(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f315d0>,
#  'LEUCINE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f31650>,
#  'LI+': <thermoengine.phases.PurePhase at 0x7f9863f31750>,
#  'LU+3': <thermoengine.phases.PurePhase at 0x7f9874dff350>,
#  'METHANE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f2fe90>,
#  'METHANOL(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f2ffd0>,
#  'MG(HCO3)+': <thermoengine.phases.PurePhase at 0x7f9863f2fd90>,
#  'MG(HSIO3)+': <thermoengine.phases.PurePhase at 0x7f9875593650>,
#  'MG+2': <thermoengine.phases.PurePhase at 0x7f9863f2fc10>,
#  'MGCL+': <thermoengine.phases.PurePhase at 0x7f988dc74110>,
#  'MGCO3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f2f2d0>,
#  'MGO(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f2f3d0>,
#  'MG(OH)+': <thermoengine.phases.PurePhase at 0x7f9863f2f1d0>,
#  'MGSIO2HCO3+': <thermoengine.phases.PurePhase at 0x7f98755939d0>,
#  'MGSO4(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f2f6d0>,
#  'MN++': <thermoengine.phases.PurePhase at 0x7f98756bce10>,
#  'MNCL+': <thermoengine.phases.PurePhase at 0x7f9863f2f7d0>,
#  'MNO4-': <thermoengine.phases.PurePhase at 0x7f9863f2f990>,
#  'MNO4-2': <thermoengine.phases.PurePhase at 0x7f9875616c90>,
#  'MNSO4(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f28f90>,
#  'MOO4-2': <thermoengine.phases.PurePhase at 0x7f9875616a10>,
#  'N2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f28390>,
#  'NA(AC)(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f28550>,
#  'NA(AC)2-': <thermoengine.phases.PurePhase at 0x7f9863f285d0>,
#  'NA+': <thermoengine.phases.PurePhase at 0x7f9863f286d0>,
#  'NACL(AQ)': <thermoengine.phases.PurePhase at 0x7f986f4bcb90>,
#  'NACO3-': <thermoengine.phases.PurePhase at 0x7f9863f288d0>,
#  'NAHCO3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f284d0>,
#  'NAHSIO3(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f28b90>,
#  'NAOH(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f28a90>,
#  'ND+3': <thermoengine.phases.PurePhase at 0x7f9875664310>,
#  'NE(AQ)': <thermoengine.phases.PurePhase at 0x7f987500d190>,
#  'NH3(AQ)': <thermoengine.phases.PurePhase at 0x7f987561d6d0>,
#  'NH4+': <thermoengine.phases.PurePhase at 0x7f9863f57650>,
#  'NI+2': <thermoengine.phases.PurePhase at 0x7f98755480d0>,
#  'NO2-': <thermoengine.phases.PurePhase at 0x7f9863f28c10>,
#  'NO3-': <thermoengine.phases.PurePhase at 0x7f9863f22890>,
#  'O2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f22910>,
#  'OH-': <thermoengine.phases.PurePhase at 0x7f9863f22ad0>,
#  'PB+2': <thermoengine.phases.PurePhase at 0x7f9874dff490>,
#  'PBCL+': <thermoengine.phases.PurePhase at 0x7f9863f22fd0>,
#  'PBCL2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f22d90>,
#  'PBCL3-': <thermoengine.phases.PurePhase at 0x7f9863f22d50>,
#  'PD+2': <thermoengine.phases.PurePhase at 0x7f9863f228d0>,
#  'PO4-3': <thermoengine.phases.PurePhase at 0x7f986f4ae150>,
#  'PR+3': <thermoengine.phases.PurePhase at 0x7f9863f221d0>,
#  'PROPANE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f220d0>,
#  'PROPANOATE-': <thermoengine.phases.PurePhase at 0x7f9863f22390>,
#  'PROPANOIC-A(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1f7d0>,
#  'PROPANOL(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f31b90>,
#  'RA+2': <thermoengine.phases.PurePhase at 0x7f9863f1fbd0>,
#  'RB+': <thermoengine.phases.PurePhase at 0x7f9863f1fc50>,
#  'REO4-': <thermoengine.phases.PurePhase at 0x7f9863f1fd10>,
#  'RN(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1fd90>,
#  'S2-2': <thermoengine.phases.PurePhase at 0x7f9863f1fed0>,
#  'S2O3-2': <thermoengine.phases.PurePhase at 0x7f9863f1ff90>,
#  'S2O4-2': <thermoengine.phases.PurePhase at 0x7f9863f1f490>,
#  'S2O5-2': <thermoengine.phases.PurePhase at 0x7f9863f1f550>,
#  'S2O6-2': <thermoengine.phases.PurePhase at 0x7f9863f1f0d0>,
#  'S2O8-2': <thermoengine.phases.PurePhase at 0x7f9863f1f1d0>,
#  'S3-': <thermoengine.phases.PurePhase at 0x7f98756bcc10>,
#  'S3-2': <thermoengine.phases.PurePhase at 0x7f9863f1f990>,
#  'S3O6-2': <thermoengine.phases.PurePhase at 0x7f9863f1f210>,
#  'S4-2': <thermoengine.phases.PurePhase at 0x7f9874dff3d0>,
#  'S4O6-2': <thermoengine.phases.PurePhase at 0x7f9863f1b950>,
#  'S5-2': <thermoengine.phases.PurePhase at 0x7f9863f1bc50>,
#  'S506-2': <thermoengine.phases.PurePhase at 0x7f9863f1bdd0>,
#  'SC+3': <thermoengine.phases.PurePhase at 0x7f9863f1be90>,
#  'SEO3-2': <thermoengine.phases.PurePhase at 0x7f9875517e90>,
#  'SEO4-2': <thermoengine.phases.PurePhase at 0x7f9863f1b8d0>,
#  'SI2O4(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1b750>,
#  'SI3O6(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1b090>,
#  'SIO2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1bb10>,
#  'SM+2': <thermoengine.phases.PurePhase at 0x7f9863f1b290>,
#  'SM+3': <thermoengine.phases.PurePhase at 0x7f9863f1b3d0>,
#  'SN+2': <thermoengine.phases.PurePhase at 0x7f9863f1b550>,
#  'SO2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f1b590>,
#  'SO3-2': <thermoengine.phases.PurePhase at 0x7f9863f17bd0>,
#  'SO4-2': <thermoengine.phases.PurePhase at 0x7f9863f17dd0>,
#  'SR+2': <thermoengine.phases.PurePhase at 0x7f98757ce810>,
#  'SRCL+': <thermoengine.phases.PurePhase at 0x7f9863f17c10>,
#  'TB+3': <thermoengine.phases.PurePhase at 0x7f9863f17910>,
#  'TL+': <thermoengine.phases.PurePhase at 0x7f9863f179d0>,
#  'TL+3': <thermoengine.phases.PurePhase at 0x7f9863f17150>,
#  'TM+3': <thermoengine.phases.PurePhase at 0x7f9863f88b50>,
#  'TOLUENE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f17e90>,
#  'U+4': <thermoengine.phases.PurePhase at 0x7f9863f17390>,
#  'UO2+2': <thermoengine.phases.PurePhase at 0x7f9863f171d0>,
#  'UREA(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f17650>,
#  'VO+2': <thermoengine.phases.PurePhase at 0x7f9863f17690>,
#  'VO2+': <thermoengine.phases.PurePhase at 0x7f9863f17590>,
#  'WO4-2': <thermoengine.phases.PurePhase at 0x7f9863f15ed0>,
#  'XE(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f15f50>,
#  'Y+3': <thermoengine.phases.PurePhase at 0x7f9863f15b90>,
#  'YB+2': <thermoengine.phases.PurePhase at 0x7f9863f15bd0>,
#  'YB+3': <thermoengine.phases.PurePhase at 0x7f9863f15090>,
#  'ZN+2': <thermoengine.phases.PurePhase at 0x7f9863f15190>,
#  'ZNCL+': <thermoengine.phases.PurePhase at 0x7f9863f15290>,
#  'ZNCL2(AQ)': <thermoengine.phases.PurePhase at 0x7f9863f15350>,
#  'ZNCL3-': <thermoengine.phases.PurePhase at 0x7f9863f154d0>}

# %%
with open('DEW2019.pkl','wb') as file:
    dill.dump(output, file)
    file.close()
